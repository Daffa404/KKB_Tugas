# %% [markdown]
# ## Install category encoder

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading https://files.pythonhosted.org/packages/44/57/fcef41c248701ee62e8325026b90c432adea35555cbc870aff9cfba23727/category_encoders-2.2.2-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 3.2MB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.19.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %% [markdown]
# ## Download dataset

# %%
# !wget https://raw.githubusercontent.com/Daffa404/KKB_Tugas/master/Final%20Project/lol_ranked_games.csv
# Out:
# --2021-01-09 23:45:46--  https://raw.githubusercontent.com/Daffa404/KKB_Tugas/master/Final%20Project/lol_ranked_games.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38679427 (37M) [text/plain]
# Saving to: ‘lol_ranked_games.csv’
#
# lol_ranked_games.cs 100%[===================>]  36.89M  63.7MB/s    in 0.6s
#
# 2021-01-09 23:45:47 (63.7 MB/s) - ‘lol_ranked_games.csv’ saved [38679427/38679427]

# %% [markdown]
# ## Import

# %%
# Utils
import pandas as pd # Dataframe
import numpy as np
import math

# Model related
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.svm import SVC # SVM
from sklearn.neighbors import KNeighborsClassifier # KNN
from sklearn.ensemble import RandomForestClassifier, VotingClassifier # Ensemble
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from category_encoders.target_encoder import TargetEncoder

# Visualisasi
from sklearn import tree # Visualisasi Decision Tree
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Persiapan dataset

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('/content/lol_ranked_games.csv')
df.head()
# Out:
#        gameId  gameDuration  hasWon  ...  wardsPlaced  wardsDestroyed  wardsLost
# 0  4546233126       1443000       1  ...           21               3          5
# 1  4546233126       1443000       1  ...           28               4          6
# 2  4546233126       1443000       1  ...           35               4          6
# 3  4546233126       1443000       1  ...           45               6         10
# 4  4546233126       1443000       1  ...           49               7         12
#
# [5 rows x 59 columns]

# %% [markdown]
# Banyaknya Id yang berbeda dari sebuah dataset

# %%
game_ids = df['gameId'].unique()
print('Ada ' + str(len(game_ids)) + ' gameId')
# Out:
# Ada 24912 gameId

# %% [markdown]
# Mengambil dari gameID yang terakhir karena pada tabel misalnya kill dead dan assist tabel terakhir merupaka penjumlahan dari tabel sebelumnya

# %%
dfo = df.copy()
df1 = dfo.groupby('gameId',as_index=False,sort=False).last()
df1.head()
# Out:
#        gameId  gameDuration  hasWon  ...  wardsPlaced  wardsDestroyed  wardsLost
# 0  4546233126       1443000       1  ...           85              11         14
# 1  4438212663       1241000       1  ...           36               7         10
# 2  4402345420       1790000       1  ...           59              16         19
# 3  4546761795       2065000       0  ...           64              14         24
# 4  4528965743       1307000       0  ...           26               3          9
#
# [5 rows x 59 columns]

# %% [markdown]
# Mengganti semua fitur menjadi object dan tsarget menjadi integer

# %%
for col in df1.columns:
  df1[col] = df1[col].astype('object')

df1['hasWon'] = df1['hasWon'].astype('int')

# %% [markdown]
# drop column yang mempunyai null-values

# %%
df1.dropna(inplace=True)
df1.describe(include='all')
# Out:
#               gameId  gameDuration  ...  wardsDestroyed  wardsLost
# count   2.491200e+04       24912.0  ...         24912.0    24912.0
# unique  2.491200e+04        2074.0  ...            91.0       95.0
# top     4.450214e+09     1210000.0  ...            12.0       12.0
# freq    1.000000e+00          54.0  ...          1145.0     1170.0
# mean             NaN           NaN  ...             NaN        NaN
# std              NaN           NaN  ...             NaN        NaN
# min              NaN           NaN  ...             NaN        NaN
# 25%              NaN           NaN  ...             NaN        NaN
# 50%              NaN           NaN  ...             NaN        NaN
# 75%              NaN           NaN  ...             NaN        NaN
# max              NaN           NaN  ...             NaN        NaN
#
# [11 rows x 59 columns]

# %% [markdown]
# Melakukan Encoder dari berdasarkan target dengan memberikan nilai 0-1

# %%
te = TargetEncoder()

# %%
X = df1[['goldDiff', 'expDiff','champLevelDiff','killedFireDrake','killedWaterDrake','killedAirDrake','killedEarthDrake','killedElderDrake','lostFireDrake','lostWaterDrake','lostAirDrake','lostEarthDrake','lostElderDrake','killedBaronNashor','lostBaronNashor','killedRiftHerald','lostRiftHerald','kills','deaths','assists','wardsPlaced','wardsDestroyed','wardsLost']] # Features
y = df1[['hasWon']] # Target variable
te.fit(X, y)
X = te.transform(X)

X.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#    goldDiff   expDiff  champLevelDiff  ...  wardsPlaced  wardsDestroyed  wardsLost
# 0  0.976445  0.503332        0.994100  ...     0.550000        0.472889   0.483304
# 1  0.866425  0.866425        1.000000  ...     0.470395        0.492253   0.566726
# 2  0.503332  0.940796        0.983193  ...     0.536023        0.536272   0.472441
# 3  0.500896  0.503332        0.005470  ...     0.467742        0.509202   0.442804
# 4  0.503332  0.135367        0.002500  ...     0.427632        0.401316   0.567647
#
# [5 rows x 23 columns]

# %% [markdown]
# ## SVM

# %% [markdown]
# Parameter yang akan di iterasi

# %%
param_svm = {
  'test_size': [0.9, 0.5, 0.3],  
  'C'    : [1, 10, 0.1],
  'gamma': [0.1, 0.01, 1.0],
  'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
}

# %% [markdown]
# Melakukan iterasi untuk mengahsilkan akurasi yang bervarisai

# %% [markdown]
# np.ravel untuk merubah array 2d menjadi 1d untuk menghindari DataConversionWarning

# %%
row_format ="{:>10}" * (len(param_svm) + 2)
print(row_format.format(*param_svm, 'akurasi', 'f1'))
acc_bfr = -math.inf
for i in param_svm['test_size']:
  for j in param_svm['C']:
    for k in param_svm['gamma']:
      for l in param_svm['kernel']:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=42)
        svc = SVC(C=j, gamma=k, kernel=l)
        svc.fit(X_train, np.ravel(y_train))
        # print(y_test)
        pred = svc.predict(X_test)
        acc = metrics.accuracy_score(y_test, pred)
        f1 = metrics.f1_score(y_test, pred)
        if(acc > acc_bfr):
          acc_bfr = acc
          best_param_svm = {'t_size': i, 'C': j, 'gamma': k, 'kernel': l, 'accuracy': acc, 'f1': f1}
        print(row_format.format(str(i), str(j), str(k), str(l), '%.3f' % acc, '%.3f' % f1))
print('best param: ', best_param_svm)
# Out:
#  test_size         C     gamma    kernel   akurasi        f1
#        0.9         1       0.1    linear     0.973     0.973
#        0.5       0.1       0.1    linear     0.971     0.972
#        0.5       0.1       0.1      poly     0.969     0.969
#        0.5       0.1       0.1       rbf     0.967     0.967
#        0.5       0.1       0.1   sigmoid     0.961     0.962
#        0.5       0.1      0.01    linear     0.971     0.972
#        0.5       0.1      0.01      poly     0.503     0.670
#        0.5       0.1      0.01       rbf     0.962     0.962
#        0.5       0.1      0.01   sigmoid     0.961     0.961
#        0.5       0.1       1.0    linear     0.971     0.972
#        0.5       0.1       1.0      poly     0.975     0.976
#        0.5       0.1       1.0       rbf     0.970     0.970
#        0.5       0.1       1.0   sigmoid     0.503     0.670
#        0.3         1       0.1    linear     0.974     0.974
#        0.3         1       0.1      poly     0.973     0.973
#        0.3         1       0.1       rbf     0.972     0.972
#        0.3         1       0.1   sigmoid     0.968     0.968
#        0.3         1      0.01    linear     0.974     0.974
#        0.3         1      0.01      poly     0.960     0.959
#        0.3         1      0.01       rbf     0.968     0.968
#        0.3         1      0.01   sigmoid     0.966     0.966
#        0.3         1       1.0    linear     0.974     0.974
#        0.3         1       1.0      poly     0.975     0.975
#        0.3         1       1.0       rbf     0.975     0.975
#        0.3         1       1.0   sigmoid     0.066     0.078
#        0.3        10       0.1    linear     0.975     0.975
#        0.3        10       0.1      poly     0.975     0.975
#        0.3        10       0.1       rbf     0.974     0.974
#        0.3        10       0.1   sigmoid     0.968     0.968
#        0.3        10      0.01    linear     0.975     0.975
#        0.3        10      0.01      poly     0.966     0.966
#        0.3        10      0.01       rbf     0.972     0.972
#        0.3        10      0.01   sigmoid     0.972     0.972
#        0.3        10       1.0    linear     0.975     0.975
#        0.3        10       1.0      poly     0.973     0.973
#        0.3        10       1.0       rbf     0.975     0.975
#        0.3        10       1.0   sigmoid     0.064     0.068
#        0.3       0.1       0.1    linear     0.972     0.972
#        0.3       0.1       0.1      poly     0.971     0.970
#        0.3       0.1       0.1       rbf     0.967     0.967
#        0.3       0.1       0.1   sigmoid     0.962     0.962
#        0.3       0.1      0.01    linear     0.972     0.972
#        0.3       0.1      0.01      poly     0.498     0.665
#        0.3       0.1      0.01       rbf     0.962     0.962
#        0.3       0.1      0.01   sigmoid     0.962     0.962
#        0.3       0.1       1.0    linear     0.972     0.972
#        0.3       0.1       1.0      poly     0.976     0.976
#        0.3       0.1       1.0       rbf     0.971     0.971
#        0.3       0.1       1.0   sigmoid     0.498     0.665
# best param:  {'t_size': 0.3, 'C': 0.1, 'gamma': 1.0, 'kernel': 'poly', 'accuracy': 0.9764516992239765, 'f1': 0.9764264666488081}

# %% [markdown]
# ## KNN

# %% [markdown]
# Parameter yang akan di iterasi

# %%
param_knn = {
  'test_size': [0.9, 0.5, 0.3],  
  'n_neighbor': [3, 5, 7],
  'weights': ['uniform', 'distance'],
  'algorithm': ['auto', 'ball_tree'],
}

# %% [markdown]
# Melakukan iterasi untuk mengahsilkan akurasi yang bervarisai

# %%
row_format ="{:>10}" * (len(param_knn) + 2)
print(row_format.format(*param_knn, 'akurasi', 'f1'))
acc_bfr = -math.inf
for i in param_knn['test_size']:
  for j in param_knn['n_neighbor']:
    for k in param_knn['weights']:
      for l in param_knn['algorithm']:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=42)
        knn = KNeighborsClassifier(n_neighbors=j, weights=k, algorithm=l)
        knn.fit(X_train, np.ravel(y_train))

        # print(y_test)
        pred = knn.predict(X_test)
        acc = metrics.accuracy_score(y_test, pred)
        f1 = metrics.f1_score(y_test, pred)
        if(acc > acc_bfr):
          acc_bfr = acc
          best_param_knn = {'t_size': i, 'n_beighbors': j, 'weights': k, 'algorithm': l, 'accuracy': acc, 'f1': f1}
        print(row_format.format(str(i), str(j), str(k), str(l), '%.3f' % acc, '%.3f' % f1))
print('best param: ', best_param_knn)
# Out:
#  test_sizen_neighbor   weights algorithm   akurasi        f1
#        0.9         3   uniform      auto     0.964     0.964
#        0.9         3   uniform ball_tree     0.964     0.964
#        0.9         3  distance      auto     0.964     0.964
#        0.9         3  distance ball_tree     0.964     0.964
#        0.9         5   uniform      auto     0.966     0.966
#        0.9         5   uniform ball_tree     0.966     0.966
#        0.9         5  distance      auto     0.966     0.966
#        0.9         5  distance ball_tree     0.966     0.966
#        0.9         7   uniform      auto     0.967     0.967
#        0.9         7   uniform ball_tree     0.967     0.967
#        0.9         7  distance      auto     0.967     0.967
#        0.9         7  distance ball_tree     0.967     0.967
#        0.5         3   uniform      auto     0.965     0.965
#        0.5         3   uniform ball_tree     0.965     0.965
#        0.5         3  distance      auto     0.965     0.965
#        0.5         3  distance ball_tree     0.965     0.965
#        0.5         5   uniform      auto     0.967     0.967
#        0.5         5   uniform ball_tree     0.967     0.967
#        0.5         5  distance      auto     0.967     0.967
#        0.5         5  distance ball_tree     0.967     0.967
#        0.5         7   uniform      auto     0.968     0.968
#        0.5         7   uniform ball_tree     0.968     0.968
#        0.5         7  distance      auto     0.968     0.968
#        0.5         7  distance ball_tree     0.968     0.968
#        0.3         3   uniform      auto     0.965     0.965
#        0.3         3   uniform ball_tree     0.965     0.965
#        0.3         3  distance      auto     0.965     0.965
#        0.3         3  distance ball_tree     0.965     0.965
#        0.3         5   uniform      auto     0.967     0.967
#        0.3         5   uniform ball_tree     0.967     0.967
#        0.3         5  distance      auto     0.967     0.967
#        0.3         5  distance ball_tree     0.967     0.967
#        0.3         7   uniform      auto     0.968     0.968
#        0.3         7   uniform ball_tree     0.968     0.968
#        0.3         7  distance      auto     0.968     0.968
#        0.3         7  distance ball_tree     0.968     0.968
# best param:  {'t_size': 0.5, 'n_beighbors': 7, 'weights': 'distance', 'algorithm': 'auto', 'accuracy': 0.9678066795118818, 'f1': 0.9680248783988519}
